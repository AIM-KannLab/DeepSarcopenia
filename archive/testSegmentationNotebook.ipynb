# %%
import argparse
import os
import warnings
from scripts.infer_segmentation import test

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
warnings.filterwarnings("ignore")
   
#if __name__ == '__main__':

#    parser = argparse.ArgumentParser(description='Bodycomposition is segmented and stored in NIFTI format.') 
    
#    parser.add_argument('--image_dir','-i', type = str, default = '../data/test/input', 
#                        help = 'File path of abdominal CT scan')
    
#    parser.add_argument('--model_weight_path','-m', type = str, default = '../model/test/L3_Top_Segmentation_Model_Weight.hdf5',
#                        help = 'File path of well-trained model weight')
    
#    parser.add_argument('--l3_slice_csv_path','-c', type = str, default = '../data/test/output_csv/L3_Top_Slice_Prediction.csv',
#                        help = 'L3 top slice number of the input CT scan')
    
#    parser.add_argument('--output_dir','-o', type = str, 
#                        default = '../data/test/output_segmentation/',
#                        help = 'File path of well-trained model weight')    
    
#    args = parser.parse_args()
#    model = test(**vars(args))

# %%
model=test('../data/test/input','../model/test/C3_Top_Segmentation_Model_Weight.hdf5','../data/test/output_csv/C3_Top_Slice_Prediction.csv','../data/test/output_segmentation/')
# Out:
# 1/1 [==============================] - 0s 359ms/step
# 2022-10-28 18:48:46.290729: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0 th image: mdacc_HNSCC-01-0005_CT-SIM-01-19-1998-_raw_raw_raw_xx (C3_slice_auto: 268 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0005_CT-SIM-01-19-1998-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 1 th image: mdacc_HNSCC-01-0006_CT-SIM-06-09-1997-_raw_raw_raw_xx (C3_slice_auto: 128 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0006_CT-SIM-06-09-1997-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 47ms/step
#
# 2 th image: mdacc_HNSCC-01-0095_CT-SIM-09-22-1999-_raw_raw_raw_xx (C3_slice_auto: 85 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0095_CT-SIM-09-22-1999-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 43ms/step
#
# 3 th image: mdacc_HNSCC-01-0096_CT-SIM-10-30-1999-_raw_raw_raw_xx (C3_slice_auto: 78 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0096_CT-SIM-10-30-1999-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 42ms/step
#
# 4 th image: mdacc_HNSCC-01-0122_CT-SIM-04-18-2000-_raw_raw_raw_xx (C3_slice_auto: 79 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0122_CT-SIM-04-18-2000-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 36ms/step
#
# 5 th image: mdacc_HNSCC-01-0123_CT-SIM-03-24-2000-_raw_raw_raw_xx (C3_slice_auto: 72 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0123_CT-SIM-03-24-2000-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 6 th image: mdacc_HNSCC-01-0124_CT-SIM-05-23-2000-_raw_raw_raw_xx (C3_slice_auto: 55 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0124_CT-SIM-05-23-2000-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 37ms/step
#
# 7 th image: mdacc_HNSCC-01-0581_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 158 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0581_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 8 th image: mdacc_HNSCC-01-0582_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 55 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0582_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 40ms/step
#
# 9 th image: mdacc_HNSCC-01-0583_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 147 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0583_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 10 th image: mdacc_HNSCC-01-0584_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 154 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0584_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 11 th image: mdacc_HNSCC-01-0585_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 139 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0585_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 57ms/step
#
# 12 th image: mdacc_HNSCC-01-0586_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 122 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0586_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 13 th image: mdacc_HNSCC-01-0587_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 164 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0587_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 14 th image: mdacc_HNSCC-01-0588_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 119 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0588_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 42ms/step
#
# 15 th image: mdacc_HNSCC-01-0589_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 70 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0589_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 62ms/step
#
# 16 th image: mdacc_HNSCC-01-0590_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 153 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0590_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 62ms/step
#
# 17 th image: mdacc_HNSCC-01-0591_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 181 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0591_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 64ms/step
#
# 18 th image: mdacc_HNSCC-01-0592_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 158 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0592_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 62ms/step
#
# 19 th image: mdacc_HNSCC-01-0593_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 166 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0593_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 61ms/step
#
# 20 th image: mdacc_HNSCC-01-0594_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 32 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0594_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 36ms/step
#
# 21 th image: mdacc_HNSCC-01-0595_CT-SIM-11-13-2011-_raw_raw_raw_xx (C3_slice_auto: 145 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0595_CT-SIM-11-13-2011-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 22 th image: mdacc_HNSCC-01-0596_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 128 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0596_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 23 th image: mdacc_HNSCC-01-0597_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 143 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0597_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 24 th image: mdacc_HNSCC-01-0598_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 135 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0598_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 25 th image: mdacc_HNSCC-01-0599_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 121 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0599_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 62ms/step
#
# 26 th image: mdacc_HNSCC-01-0600_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 33 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0600_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 38ms/step
#
# 27 th image: mdacc_HNSCC-01-0601_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 121 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0601_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 28 th image: mdacc_HNSCC-01-0602_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 137 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0602_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 29 th image: mdacc_HNSCC-01-0603_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 148 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0603_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 46ms/step
#
# 30 th image: mdacc_HNSCC-01-0604_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 125 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0604_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
# 1/1 [==============================] - 0s 61ms/step
#
# 31 th image: mdacc_HNSCC-01-0605_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 144 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0605_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 32 th image: mdacc_HNSCC-01-0606_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 56 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0606_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 33 th image: mdacc_HNSCC-01-0608_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 171 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0608_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 62ms/step
#
# 34 th image: mdacc_HNSCC-01-0609_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 154 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0609_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 35 th image: mdacc_HNSCC-01-0610_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 148 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0610_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 57ms/step
#
# 36 th image: mdacc_HNSCC-01-0611_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 137 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0611_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 37 th image: mdacc_HNSCC-01-0612_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 150 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0612_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 38 th image: mdacc_HNSCC-01-0613_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 62 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0613_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 39ms/step
#
# 39 th image: mdacc_HNSCC-01-0614_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 156 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0614_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 40 th image: mdacc_HNSCC-01-0615_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 126 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0615_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 41 th image: mdacc_HNSCC-01-0616_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 128 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0616_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 55ms/step
#
# 42 th image: mdacc_HNSCC-01-0617_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 154 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0617_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 43 th image: mdacc_HNSCC-01-0618_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 136 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0618_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 58ms/step
#
# 44 th image: mdacc_HNSCC-01-0619_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 44 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0619_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 36ms/step
#
# 45 th image: mdacc_HNSCC-01-0620_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 147 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0620_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 46 th image: mdacc_HNSCC-01-0621_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 165 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0621_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 59ms/step
#
# 47 th image: mdacc_HNSCC-01-0622_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 185 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0622_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 60ms/step
#
# 48 th image: mdacc_HNSCC-01-0623_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 156 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0623_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 49 th image: mdacc_HNSCC-01-0624_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 52 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0624_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 49ms/step
#
# 50 th image: mdacc_HNSCC-01-0625_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 187 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0625_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 53ms/step
#
# 51 th image: mdacc_HNSCC-01-0626_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 144 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0626_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 57ms/step
#
# 52 th image: mdacc_HNSCC-01-0627_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 154 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0627_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 53 th image: mdacc_HNSCC-01-0628_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 60 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0628_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 45ms/step
#
# 54 th image: mdacc_HNSCC-01-0629_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 152 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0629_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
#
# 1/1 [==============================] - 0s 56ms/step
#
# 55 th image: mdacc_HNSCC-01-0630_CT-SIM-12-16-2012-_raw_raw_raw_xx (C3_slice_auto: 126 )  segmentation_in_NIFTI saved into
# ../data/test/output_segmentation/mdacc_HNSCC-01-0630_CT-SIM-12-16-2012-_raw_raw_raw_xx.seg.nrrd
